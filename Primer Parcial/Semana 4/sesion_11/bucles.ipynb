# %% [markdown]
# ##### **Sesión 11 - Programación para Ciencia de Datos 2026-1 - 24 Septiembre 2025**
# ---
# # **Bucles for y while en Python**
#
# Crear un notebook llamado `bucles.ipynb` con al menos **5 ejercicios resueltos** usando `for y while`.
#
# ---
# ##### **Ejercicios:**
#
# ##### **🔹 Ejercicio 1:** Adivinar el numero

# %%
import random

print("     -> ADIVINANDO EL NUMERO")
print("--------------------------------------------------------------------")
print("pensaré un número del 1 al 50 y tú lo adivinarás")

numero_secreto = random.randint(1, 50)
intentos = 0

while True:
    try:
        intento = int(input("\n¿Qué número crees que es? (1-50): "))
        intentos += 1

        if intento < 1 or intento > 50:
            print("El número debe estar entre 1 y 50, intenta de nuevo")
            
            continue

        if intento < numero_secreto:
            print("El numero que ingresaste es menor al que pensé")
        elif intento > numero_secreto:
            print("El numero que ingresaste es mayor al que pensé")
        else:
            print(f"\nAdivinasteeeeeeeeeeeeeeee en {intentos} intentos")
            print(f"El número era: {numero_secreto}")
            break
            
    except ValueError:
        print("Ingresa solo números")

print("\n--------------------------------------------------------------------")
print("Fin del juego")
# Out:
#      -> ADIVINANDO EL NUMERO
# --------------------------------------------------------------------
# pensaré un número del 1 al 50 y tú lo adivinarás
# El numero que ingresaste es menor al que pensé
# El numero que ingresaste es mayor al que pensé
# El numero que ingresaste es mayor al que pensé
#
# Adivinasteeeeeeeeeeeeeeee en 4 intentos
# El número era: 26
#
# --------------------------------------------------------------------
# Fin del juego

# %% [markdown]
# ##### **🔹 Ejercicio 2:** Lista de compras

# %%
print("     -> LISTA DE COMPRAS")
print("--------------------------------------------------------------------")
print("Agrega productos a la lista de compras. Escribe 'fin' para terminar\n")

lista_compras = []
total_productos = 0

while True:
    producto = input("¿Qué producto quieres agregar? (escribe 'fin' para terminar): \n")
    
    if producto.lower() == 'fin':
        break
    
    if producto.strip() == "":
        print("Debes escribir un producto")
        continue
    
    lista_compras.append(producto)
    total_productos += 1
    print(f"Agregué: {producto}")

print("\n--------------------------------------------------------------------")
print("Lista de compras:\n")

if total_productos > 0:
    for i, producto in enumerate(lista_compras, 1):
        print(f"{i}. {producto}")
    
    print(f"\nTotal de productos: {total_productos}")
else:
    print("\nTu lista está vacía")

print("\n--------------------------------------------------------------------")
print("Fin de la lista")
# Out:
#      -> LISTA DE COMPRAS
# --------------------------------------------------------------------
# Agrega productos a la lista de compras. Escribe 'fin' para terminar
#
# Agregué: leche
# Agregué: cereal
# Agregué: café
# Agregué: queso
# Agregué: pan
#
# --------------------------------------------------------------------
# Lista de compras:
#
# 1. leche
# 2. cereal
# 3. café
# 4. queso
# 5. pan
#
# Total de productos: 5
#
# --------------------------------------------------------------------
# Fin de la lista

# %% [markdown]
# ##### **🔹 Ejercicio 3:** Tablas de multiplicar

# %%
print("     -> TABLAS DE MULTIPLICAR")
print("--------------------------------------------------------------------")
print("Te mostraré las tablas de multiplicar del 1 al 10:\n")

tabla_especifica = input("Quieres ver una tabla específica? (si/no): ")

if tabla_especifica.lower() in ['sí', 'si', 's', 'yes']:
    try:
        numero = int(input("Qué tabla quieres ver? (1-10): "))
        if 1 <= numero <= 10:
            print(f"\nTABLA DEL {numero}:")
            print("--------------------------------------------------------------------")
            for i in range(1, 11):
                resultado = numero * i
                print(f"{numero} × {i} = {resultado}")
        else:
            print("El número debe estar entre 1 y 10")
    except ValueError:
        print("Debes ingresar un número")
else:
    print("\nTABLAS DEL 1 AL 10:")
    print("--------------------------------------------------------------------")
    
    for tabla in range(1, 11):
        print(f"\nTabla del {tabla}:")
        print("--------------------------------------------------------------------")
        
        for multiplicador in range(1, 11):
            resultado = tabla * multiplicador
            print(f"{tabla} × {multiplicador} = {resultado}")

print("\n--------------------------------------------------------------------")
print("Fin de las tablas")
# Out:
#      -> TABLAS DE MULTIPLICAR
# --------------------------------------------------------------------
# Te mostraré las tablas de multiplicar del 1 al 10:
#
#
# TABLA DEL 7:
# --------------------------------------------------------------------
# 7 × 1 = 7
# 7 × 2 = 14
# 7 × 3 = 21
# 7 × 4 = 28
# 7 × 5 = 35
# 7 × 6 = 42
# 7 × 7 = 49
# 7 × 8 = 56
# 7 × 9 = 63
# 7 × 10 = 70
#
# --------------------------------------------------------------------
# Fin de las tablas

# %% [markdown]
# ##### **🔹 Ejercicio 4:** Calculadora de estadísticas

# %%
print("     ->CALCULADORA DE ESTADÍSTICAS")
print("--------------------------------------------------------------------")
print("Ingresa números y te daré estadísticas, escribe 'fin' para terminar\n")

numeros = []
contador = 0

while True:
    entrada = input("Ingresa un número (o 'fin' para terminar): ")
    
    if entrada.lower() == 'fin':
        break
    
    try:
        numero = float(entrada)
        numeros.append(numero)
        contador += 1
        print(f"Número {contador}: {numero}")
    except ValueError:
        print("Por favor, ingresa solo números")

if len(numeros) > 0:
    print("\n--------------------------------------------------------------------")
    print("RESULTADOS:")
    print("--------------------------------------------------------------------\n")

    total = sum(numeros)
    promedio = total / len(numeros)
    
    maximo = max(numeros)
    minimo = min(numeros)
    
    print("- Números ingresados:", numeros)
    print(f"- Cantidad de números: {len(numeros)}")
    print(f"- Suma total: {total}")
    print(f"- Promedio: {promedio:.2f}")
    print(f"- Número más grande: {maximo}")
    print(f"- Número más pequeño: {minimo}")
    
else:
    print("\nNo ingresaste ningún número para analizar")

print("\n--------------------------------------------------------------------")
print("Fin de la calculadora")
# Out:
#      ->CALCULADORA DE ESTADÍSTICAS
# --------------------------------------------------------------------
# Ingresa números y te daré estadísticas, escribe 'fin' para terminar
#
# Número 1: 3.0
# Número 2: 4.0
# Número 3: 5.0
# Número 4: 6.0
# Número 5: 7.0
# Número 6: 5.0
# Número 7: 6.0
# Número 8: 5.0
# Número 9: 5.0
# Número 10: 5.0
#
# --------------------------------------------------------------------
# RESULTADOS:
# --------------------------------------------------------------------
#
# - Números ingresados: [3.0, 4.0, 5.0, 6.0, 7.0, 5.0, 6.0, 5.0, 5.0, 5.0]
# - Cantidad de números: 10
# - Suma total: 51.0
# - Promedio: 5.10
# - Número más grande: 7.0
# - Número más pequeño: 3.0
#
# --------------------------------------------------------------------
# Fin de la calculadora

# %% [markdown]
# ##### **🔹 Ejercicio 5:** Contador de vocales

# %%
print("     -> CONTADOR DE VOCALES")
print("--------------------------------------------------------------------")
print("Te diré cuántas vocales tiene cualquier palabra u oración")

texto = input("\nEscribe una palabra u oración: ")
texto_minusculas = texto.lower()

vocales = 'aeiouáéíóú'

total_vocales = 0
contador_a = 0
contador_e = 0
contador_i = 0
contador_o = 0
contador_u = 0

for letra in texto_minusculas:
    if letra in vocales:
        total_vocales += 1
        
        if letra in 'aá':
            contador_a += 1
        elif letra in 'eé':
            contador_e += 1
        elif letra in 'ií':
            contador_i += 1
        elif letra in 'oó':
            contador_o += 1
        elif letra in 'uú':
            contador_u += 1

print("--------------------------------------------------------------------")
print("RESULTADOS:")
print("--------------------------------------------------------------------")

if total_vocales > 0:
    print(f"Total de vocales: {total_vocales}")
    print("\nDesglose por vocal:")
    print(f"   A: {contador_a}")
    print(f"   E: {contador_e}")
    print(f"   I: {contador_i}")
    print(f"   O: {contador_o}")
    print(f"   U: {contador_u}")

else:
    print("No se encontraron vocales en el texto")

print(f"\nTexto original: \"{texto}\"")
print("\n--------------------------------------------------------------------")
print("Fin del contador")
# Out:
#      -> CONTADOR DE VOCALES
# --------------------------------------------------------------------
# Te diré cuántas vocales tiene cualquier palabra u oración
# --------------------------------------------------------------------
# RESULTADOS:
# --------------------------------------------------------------------
# Total de vocales: 15
#
# Desglose por vocal:
#    A: 5
#    E: 7
#    I: 1
#    O: 1
#    U: 1
#
# Texto original: "esta es la tarea de la sesión 11 de bucles"
#
# --------------------------------------------------------------------
# Fin del contador
