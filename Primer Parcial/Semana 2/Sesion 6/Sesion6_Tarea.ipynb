# %% [markdown]
# ##### **Sesión 06 - Programación para Ciencia de Datos 2026-1 - 28 Septiembre 2025**

# %% [markdown]
# # VENTAJAS DE USAR VISUAL STUDIO CODE
#
# ## 1. Gratito y multiplataforma
# - Funciona en Windows, macOs y Linux.
# - No necesitas pagar licencias.
#
# ## 2. Ligero pero potente
# - Arranca rápido y consume menos recursos que IDEs grandes como PyCharm o Eclipse.
# - Ideal si trabajas con una Pc con recursos limitados.
#
# ## 3. Extensiones y personalización
# - Tiene un marketplace gigante con extensiones:
#     - Python, R, C++, Java, etc.
#     - Integración con Git, Docker, Jupyter Notebook.
#     - Temas y atajos personalizados.
# - Puedes adaptar VS Code a tu estilo de trabajo.
#
# ## 4. Soporte para múltuples lenguajes
# - Admite más de 30 lenguajes de programación directamente, y con extensiones casi cualquiera.
#
# ## 5. Integración con Git y GitHub
# - Puedes hacer commits, push y pull sin salir del editor.
#
# ## 6. Depuración integrada
# - Permite poner breakpoints, inspeccionar variables y depurar código paso a paso.
#
# ## 7. Soporte para Jupyter Notebooks
# - Puedes abrir y correr archivos .ipynb (como en Google Colab o Jupyter) directamente en VS Code.
#
# ## 8. Terminal integrado
# - Puedes ejecutar Python, Git, Bash, etc. desde el mismo editor.
#
# ## 9. Autocompletado e IntelliSence
# - Te sugiere código mientras escribes.
# - Reconoce funciones, variables y documentación de las librerías que usas.
#
# ## 10. Comunidad enorme
# - Al ser tan popular, hay miles de tutoriales, foros y documentación.
# - Muy fácil encontrar soluciones a problemas.

# %% [markdown]
# ##### **Sesión 11 - Programación para Ciencia de Datos 2026-1 - 24 Septiembre 2025**
# ---
# # **Bucles for y while en Python**
#
# Crear un notebook llamado `bucles.ipynb` con al menos **5 ejercicios resueltos** usando `for y while`.
#
# ---
# ##### **Ejercicios:**
#
# ##### **🔹 Ejercicio 1:** Adivinar el numero

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Leer el archivo CSV
df = pd.read_csv("airlines_flights_data.csv")

# Crear gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='duration', y='price', alpha=0.5)

# Etiquetas
plt.title("Relación entre duración del vuelo y precio")
plt.xlabel("Duración del vuelo (horas)")
plt.ylabel("Precio del vuelo (USD)")
plt.grid(True)
plt.tight_layout()
plt.show()
